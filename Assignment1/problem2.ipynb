# %% [markdown]
# # Problem #2

# %% [markdown]
# $F$<sub>0</sub>$=2$ <br />
# $F$<sub>1</sub>$=4$ <br />
# $F$<sub>2</sub>$=16$ <br />
# $F$<sub>3</sub>$=256$ <br />
# $F$<sub>4</sub>$=65536$ <br />
# $F$<sub>5</sub>$=4294967296$ <br />

# %% [markdown]
# Now, the range of values that can be stored in a 4-byte integer is $[-(2^{15}-1)$ to $2^{15}-1]=[-32767$ to $32767]$ <br/>
# With this, the highest F<sub>n</sub> value that can be stored is that of $n=3$

# %% [markdown]
# The highest value that can be stored in an 8-byte long integer is $[-(2^{31}-1)$ to $2^{31}-1]=[-2147483647$ to $2147483647]$ <br/>
# With this, the highest F<sub>n</sub> value that can be stored is that of $n=4$

# %% [markdown]
# The highest value that can be stored in an 8-byte unsigned long integer is $(2^{32}-1)=4294967295$ <br/>
# With this, the highest F<sub>n</sub> value that can be stored is that of $n=4$
