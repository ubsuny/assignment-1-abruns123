# %% [markdown]
# # Problem #1

# %% [markdown]
# $10 = 2^{1}+2^{3}=0000 0000 0000 1010$ <br />
# $436 =2^{2}+2^{4}+2^{5}+2^{7}+2^{8} = 0000 0001 1011 0100$ <br />
# $1024 = 2^{10}= 0000 0100 0000 0000$ <br />
# $-13$: <br/> Now, $13=2^{3}+2^{2}+2^{1} =0000 0000 0000 1110$ <br /> Flipping the zeros/ones and adding one gives: $-13 = 1111 1111 1111 0011$ <br />
# $-1023$:<br/> Now, $1023=2^{9}+2^{8}+2^{7}+2^{6}+2^{5}+2^{4}+2^{3}+2^{2}+2^{1}+2^{0}=0000 0011 1111 1111$ <br/>
# Flipping the zeros/ones and adding one gives $-1023=1111 1100 0000 0001$ <br />
# $-1024$:<br/>
# Flipping the zeros/ones of 1024 and adding 1 gives $-1024=1111 1100 0000 0000$ <br />
